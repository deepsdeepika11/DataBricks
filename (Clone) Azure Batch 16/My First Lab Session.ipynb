# %%
text = "hello world"
print(text)
print(f"Number of letters: {len(text.replace(' ', ''))}")

# %% [markdown]
# HELLO WORLD

# %%
# %sql
SELECT * 
FROM samples.bakehouse.sales_suppliers;

# %%
print(spark)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Databricks Shell") \
    .getOrCreate()

print(spark)
