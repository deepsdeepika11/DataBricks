# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
#df = df.rdd.getPartitions()  no of partions
#df.rdd.collect();

# %%
# %sql
Select * from workspace.default.wal_mart_1

# %%
df = spark.sql("Select * from  workspace.default.wal_mart_1")

# %%
df.display()

# %%
df = df.groupBy("product_id").agg(count("order_id"))

# %%
df.display()
