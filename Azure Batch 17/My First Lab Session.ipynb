# %%
df= spark.read.format('csv')\
                .option('header','true')\
                .option('inferSchema','true')\
                .load("/Volumes/workspace/default/pyspark_lab_1_csv")

# %%
df.show()

# %%
df.collect()

# %%
df.display()

# %%
 df.createOrReplaceTempView('Employee')

# %%
# %sql
select * from Employee
